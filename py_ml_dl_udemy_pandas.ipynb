# %%
import numpy as np

# %%
import pandas as pd

# %%
myindex = ['USA','INDIA','CANADA']

# %%
mydata = [1776,1947,1821]

# %%
myseries = pd.Series(data=mydata)
#note that 'Series' is case sensitive, and its data, then index`

# %%
myseries
# Out:
# 0    1776
# 1    1947
# 2    1821
# dtype: int64

# %%
type(myseries)
# Out:
# pandas.core.series.Series

# %%
myser = pd.Series(data=mydata,index=myindex)

# %%
myser
# Out:
# USA       1776
# INDIA     1947
# CANADA    1821
# dtype: int64

# %%
myser[0]
# Out:
# 1776

# %%
myser['INDIA']
# Out:
# 1947

# %%
ages = {'Sam': 7, 'Spike': 27, 'Wayne': 56}
#panda series can ve created from dictionaries

# %%
pd.Series(ages)
# Out:
# Sam       7
# Spike    27
# Wayne    56
# dtype: int64

# %%
q1 = {'Japan':80, 'China':450, 'India':200, 'USA':250}
q2 = {'Brazil':100, 'China':500, 'India':210, 'USA':260}

# %%
sales_q1 = pd.Series(q1)

# %%
sales_q2 = pd.Series(q2)

# %%
sales_q1.keys()
# Out:
# Index(['Japan', 'China', 'India', 'USA'], dtype='object')

# %%
[1,2]*3
# Out:
# [1, 2, 1, 2, 1, 2]

# %%
np.array([1,2])*3
# Out:
# array([3, 6])

# %%
sales_q1.loc[sales_q1==80]
# Out:
# China    450
# India    200
# USA      250
# dtype: int64

# %%
sales_q1.loc[sales_q1==80].index[0]
# Out:
# 'Japan'

# %%
sales_q1.loc[sales_q1>100]
# Out:
# China    450
# India    200
# USA      250
# dtype: int64

# %%
sales_q1+sales_q2
# Out:
# Brazil      NaN
# China     950.0
# India     410.0
# Japan       NaN
# USA       510.0
# dtype: float64

# %%
sales_q1*2
# Out:
# Japan    160
# China    900
# India    400
# USA      500
# dtype: int64

# %%
sales_q1.add(sales_q2)
# Out:
# Brazil      NaN
# China     950.0
# India     410.0
# Japan       NaN
# USA       510.0
# dtype: float64

# %%
total_sales=sales_q1.add(sales_q2,fill_value=0)
total_sales
# to add both, add fill_value bc if not, it pandas doesnt displays NaN when index is not in Both of the series
# also note that results is always float
# Out:
# Brazil    100.0
# China     950.0
# India     410.0
# Japan      80.0
# USA       510.0
# dtype: float64

# %%
type(total_sales)
# Out:
# pandas.core.series.Series

# %%
total_sales.dtype
# Out:
# dtype('float64')

# %%
sales_q1.dtype
# Out:
# dtype('int64')

# %%
#data frames
np.random.seed(101)

# %%
mydata = np.random.randint(0,101,(4,3))
mydata
# Out:
# array([[40, 60, 92],
#        [64,  5, 12],
#        [93, 40, 49],
#        [83,  8, 29]])

# %%
myindex = ['CA','NY','AZ','TX']

# %%
mycolumns = ['Jan', 'Feb', 'Mar']

# %%
df = pd.DataFrame(data=mydata,index=myindex,columns=mycolumns)
df
#note that 'DataFrame' is case sensitive in pandas
# Out:
#     Jan  Feb  Mar
# CA   40   60   92
# NY   64    5   12
# AZ   93   40   49
# TX   83    8   29

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, CA to TX
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Jan     4 non-null      int64
#  1   Feb     4 non-null      int64
#  2   Mar     4 non-null      int64
# dtypes: int64(3)
# memory usage: 128.0+ bytes

# %%
# to find python code is located
# !pwd
# Out:
# /Users/ada4sh/Documents/Study/Python/Python for ML and DScience

# %%
# !ls -l
# Out:
# total 192
# drwx------@ 29 ada4sh  staff    928 Mar 20 13:08 UNZIP_FOR_NOTEBOOKS_FINAL
# -rw-r--r--   1 ada4sh  staff  33951 Apr 13 11:34 py_ml_dl_udemy_1.ipynb
# -rw-r--r--   1 ada4sh  staff  37692 Apr 19 17:58 py_ml_dl_udemy_numpy_1.ipynb
# -rw-r--r--   1 ada4sh  staff  14496 Apr 28 12:45 py_ml_dl_udemy_pandas.ipynb
# -rw-r--r--@  1 ada4sh  staff    221 Mar 20 13:10 requirements.txt

# %%
# !ls -l UNZIP_FOR_NOTEBOOKS_FINAL/03-Pandas
# Out:
# total 53120
# -rw-r--r--@ 1 ada4sh  staff    565390 May 26  2021 00-Series.ipynb
# -rw-r--r--@ 1 ada4sh  staff    208957 Sep  8  2020 01-DataFrames.ipynb
# -rw-r--r--@ 1 ada4sh  staff    194591 Sep  8  2020 02-Conditional-Filtering.ipynb
# -rw-r--r--@ 1 ada4sh  staff    196385 Aug 12  2020 03-Useful-Methods.ipynb
# -rw-r--r--@ 1 ada4sh  staff     64227 Jul  1  2020 04-Missing-Data.ipynb
# -rw-r--r--@ 1 ada4sh  staff    219627 Jul  4  2020 05-Groupby-Operations-and-MultiIndex.ipynb
# -rw-r--r--@ 1 ada4sh  staff     62966 Jul  4  2020 06-Combining-DataFrames.ipynb
# -rw-r--r--@ 1 ada4sh  staff     32972 Sep 25  2020 07-Text-Methods.ipynb
# -rw-r--r--@ 1 ada4sh  staff     93392 Sep  8  2020 08-Time-Methods.ipynb
# -rw-r--r--@ 1 ada4sh  staff     65234 Sep 25  2020 09-Inputs-and-Outputs.ipynb
# -rw-r--r--@ 1 ada4sh  staff    101081 Sep 25  2020 10-Pivot-Tables.ipynb
# -rw-r--r--@ 1 ada4sh  staff     47135 Sep 27  2020 11-Pandas-Project-Exercise .ipynb
# ...

# %%
df1 = pd.read_csv('/Users/ada4sh/Documents/Study/Python/Python for ML and DScience/UNZIP_FOR_NOTEBOOKS_FINAL/03-Pandas/tips.csv')

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49  \
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df1.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'price_per_person', 'Payer Name', 'CC Number', 'Payment ID'],
#       dtype='object')

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
df1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49  \
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df1.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68  \
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#           Payer Name         CC Number Payment ID
# 239    Michael Avila  5296068606052842    Sat2657
# 240   Monica Sanders  3506806155565404    Sat1766
# 241       Keith Wong  6011891618747196    Sat3880
# 242     Dennis Dixon     4375220550950      Sat17
# 243  Michelle Hardin  3511451626698139    Thur672

# %%
df1.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49  \
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df1.head(20)
# Out:
#     total_bill   tip     sex smoker  day    time  size  price_per_person
# 0        16.99  1.01  Female     No  Sun  Dinner     2              8.49  \
# 1        10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2        21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3        23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4        24.59  3.61  Female     No  Sun  Dinner     4              6.15
# 5        25.29  4.71    Male     No  Sun  Dinner     4              6.32
# 6         8.77  2.00    Male     No  Sun  Dinner     2              4.38
# 7        26.88  3.12    Male     No  Sun  Dinner     4              6.72
# 8        15.04  1.96    Male     No  Sun  Dinner     2              7.52
# 9        14.78  3.23    Male     No  Sun  Dinner     2              7.39
# 10       10.27  1.71    Male     No  Sun  Dinner     2              5.14
# 11       35.26  5.00  Female     No  Sun  Dinner     4              8.82
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 21.1+ KB

# %%
df1.describe()
# Out:
#        total_bill         tip        size  price_per_person     CC Number
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    19.785943    2.998279    2.569672          7.888197  2.563496e+15
# std      8.902412    1.383638    0.951100          2.914234  2.369340e+15
# min      3.070000    1.000000    1.000000          2.880000  6.040679e+10
# 25%     13.347500    2.000000    2.000000          5.800000  3.040731e+13
# 50%     17.795000    2.900000    2.000000          7.255000  3.525318e+15
# 75%     24.127500    3.562500    3.000000          9.390000  4.553675e+15
# max     50.810000   10.000000    6.000000         20.270000  6.596454e+15

# %%
df1.describe().transpose()
# Out:
#                   count          mean           std           min
# total_bill        244.0  1.978594e+01  8.902412e+00  3.070000e+00  \
# tip               244.0  2.998279e+00  1.383638e+00  1.000000e+00
# size              244.0  2.569672e+00  9.510998e-01  1.000000e+00
# price_per_person  244.0  7.888197e+00  2.914234e+00  2.880000e+00
# CC Number         244.0  2.563496e+15  2.369340e+15  6.040679e+10
#
#                            25%           50%           75%           max
# total_bill        1.334750e+01  1.779500e+01  2.412750e+01  5.081000e+01
# tip               2.000000e+00  2.900000e+00  3.562500e+00  1.000000e+01
# size              2.000000e+00  2.000000e+00  3.000000e+00  6.000000e+00
# price_per_person  5.800000e+00  7.255000e+00  9.390000e+00  2.027000e+01
# CC Number         3.040731e+13  3.525318e+15  4.553675e+15  6.596454e+15

# %%
df1['total_bill']
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
#OR
mycols = df1[['total_bill','tip']]
mycols
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 239       29.03  5.92
# 240       27.18  2.00
# 241       22.67  2.00
# 242       17.82  1.75
# 243       18.78  3.00
#
# [244 rows x 2 columns]

# %%
df1['total_bill']+df1['tip']
# Out:
# 0      18.00
# 1      12.00
# 2      24.51
# 3      26.99
# 4      28.20
#        ...
# 239    34.95
# 240    29.18
# 241    24.67
# 242    19.57
# 243    21.78
# Length: 244, dtype: float64

# %%
tipperc = df1['tip']/df1['total_bill'] * 100
tipperc
# Out:
# 0       5.944673
# 1      16.054159
# 2      16.658734
# 3      13.978041
# 4      14.680765
#          ...
# 239    20.392697
# 240     7.358352
# 241     8.822232
# 242     9.820426
# 243    15.974441
# Length: 244, dtype: float64

# %%
df1['tip_percentage'] = tipperc
#adding new columns to df

# %%
df1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49  \
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID  tip_percentage
# 0  Christy Cunningham  3560325168603410    Sun2959        5.944673
# 1      Douglas Tucker  4478071379779230    Sun4608       16.054159
# 2      Travis Walters  6011812112971322    Sun4458       16.658734
# 3    Nathaniel Harris  4676137647685994    Sun5260       13.978041
# 4        Tonya Carter  4832732618637221    Sun2251       14.680765

# %%
df1['price_per_person'] = df1['total_bill']/df1['size']
#if columns already exists, then values are overwritten

# %%
df1['price_per_person'] = np.round(df1['total_bill']/df1['size'],2)

# %%
#dropping a column; axis = 0 is default, and changes are not permanent 
df1.drop('tip_percentage',axis=1)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49  \
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49  \
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID  tip_percentage
# ...

# %%
# changes to df are not permanets becasue of 'inplace = false' as default parameter for drop function
# good practice to permanently drop columns is below 
df1 = df1.drop('tip_percentage',axis=1)

# %%
df1.shape
# Out:
# (244, 11)

# %%
df1.shape[0]
# Out:
# 244

# %%
df1.shape[1]
# Out:
# 11

# %%
df1.set_index('Payment ID')
# Out:
#             total_bill   tip     sex smoker   day    time  size
# Payment ID
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2  \
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# ...

# %%
df1 = df1.set_index('Payment ID')

# %%
df1 = df1.reset_index('Payment ID')

# %%
df1.head()
# Out:
#   Payment ID  total_bill   tip     sex smoker  day    time  size
# 0    Sun2959       16.99  1.01  Female     No  Sun  Dinner     2  \
# 1    Sun4608       10.34  1.66    Male     No  Sun  Dinner     3
# 2    Sun4458       21.01  3.50    Male     No  Sun  Dinner     3
# 3    Sun5260       23.68  3.31    Male     No  Sun  Dinner     2
# 4    Sun2251       24.59  3.61  Female     No  Sun  Dinner     4
#
#    price_per_person          Payer Name         CC Number
# 0              8.49  Christy Cunningham  3560325168603410
# 1              3.45      Douglas Tucker  4478071379779230
# 2              7.00      Travis Walters  6011812112971322
# 3             11.84    Nathaniel Harris  4676137647685994
# 4              6.15        Tonya Carter  4832732618637221

# %%
df1 = df1.set_index('Payment ID')
df1.iloc[0]
#integer based index location
# Out:
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                  8.49
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# Name: Sun2959, dtype: object

# %%
df1.loc['Sun2959']
#label based index location
# Out:
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                  8.49
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# Name: Sun2959, dtype: object

# %%
df1.iloc[0:4]
#slicing works here
# Out:
#             total_bill   tip     sex smoker  day    time  size
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2  \
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# Sun4458                 7.00      Travis Walters  6011812112971322
# Sun5260                11.84    Nathaniel Harris  4676137647685994

# %%
df1.loc[['Sun2959','Sun5260']]
# Out:
#             total_bill   tip     sex smoker  day    time  size
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2  \
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun5260                11.84    Nathaniel Harris  4676137647685994

# %%
#dropping a row ; to make it permanent, re-assign, default axis = 0, so no need, but good to add
df1.drop('Sun2959', axis=0)
# Out:
#             total_bill   tip     sex smoker   day    time  size
# Payment ID
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3  \
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# Sun9679          25.29  4.71    Male     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person        Payer Name         CC Number
# Payment ID
# Sun4608                 3.45    Douglas Tucker  4478071379779230
# ...

# %%
#for index based dropping, instead of drop(), cuz it wont work, select rows you want instead 
df1[1:]
# Out:
#             total_bill   tip     sex smoker   day    time  size
# Payment ID
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3  \
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# Sun9679          25.29  4.71    Male     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person        Payer Name         CC Number
# Payment ID
# Sun4608                 3.45    Douglas Tucker  4478071379779230
# ...

# %%
first_row = df1.iloc[0]
first_row
# Out:
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                  8.49
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# Name: Sun2959, dtype: object

# %%
df1 = df1.set_index('Payment ID')

# %%
df1
# Out:
#             total_bill   tip     sex smoker   day    time  size
# Payment ID
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2  \
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# ...

# %%
first_row = df1.iloc[0]
first_row
# Out:
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                  8.49
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# Name: Sun2959, dtype: object

# %%
df1 = df1.append(first_row)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[177], line 1
# ----> 1 df1 = df1.append(first_row)
#
# File ~/opt/anaconda3/envs/python_udemy_ml_dl_env/lib/python3.11/site-packages/pandas/core/generic.py:5989, in NDFrame.__getattr__(self, name)
#    5982 if (
#    5983     name not in self._internal_names_set
#    5984     and name not in self._metadata
#    5985     and name not in self._accessors
#    5986     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987 ):
#    5988     return self[name]
# -> 5989 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
#columns are features 
#rows are instances of data

# %%
df = pd.read_csv('/Users/ada4sh/Documents/Study/Python/Python for ML and DScience/UNZIP_FOR_NOTEBOOKS_FINAL/03-Pandas/tips.csv')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49  \
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
#conditional filtering
df['total_bill'] >40
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240    False
# 241    False
# 242    False
# 243    False
# Name: total_bill, Length: 244, dtype: bool

# %%
bool_series = df['total_bill'] >40

# %%
df[bool_series]
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07  \
# 95        40.17   4.73    Male    Yes   Fri  Dinner     4             10.04
# 102       44.30   2.50  Female    Yes   Sat  Dinner     3             14.77
# 142       41.19   5.00    Male     No  Thur   Lunch     5              8.24
# 156       48.17   5.00    Male     No   Sun  Dinner     6              8.03
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3             15.12
# 184       40.55   3.00    Male    Yes   Sun  Dinner     2             20.27
# 197       43.11   5.00  Female    Yes  Thur   Lunch     4             10.78
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
#
#           Payer Name         CC Number Payment ID
# 59       Brian Ortiz  6596453823950595    Sat8139
# ...

# %%
df[bool_series].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, 59 to 212
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        10 non-null     float64
#  1   tip               10 non-null     float64
#  2   sex               10 non-null     object
#  3   smoker            10 non-null     object
#  4   day               10 non-null     object
#  5   time              10 non-null     object
#  6   size              10 non-null     int64
#  7   price_per_person  10 non-null     float64
#  8   Payer Name        10 non-null     object
#  9   CC Number         10 non-null     int64
#  10  Payment ID        10 non-null     object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 960.0+ bytes

# %%
df[df['total_bill'] >40]
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07  \
# 95        40.17   4.73    Male    Yes   Fri  Dinner     4             10.04
# 102       44.30   2.50  Female    Yes   Sat  Dinner     3             14.77
# 142       41.19   5.00    Male     No  Thur   Lunch     5              8.24
# 156       48.17   5.00    Male     No   Sun  Dinner     6              8.03
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3             15.12
# 184       40.55   3.00    Male    Yes   Sun  Dinner     2             20.27
# 197       43.11   5.00  Female    Yes  Thur   Lunch     4             10.78
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
#
#           Payer Name         CC Number Payment ID
# 59       Brian Ortiz  6596453823950595    Sat8139
# ...

# %%
df[df['sex'] == 'Male']
# Out:
#      total_bill   tip   sex smoker  day    time  size  price_per_person
# 1         10.34  1.66  Male     No  Sun  Dinner     3              3.45  \
# 2         21.01  3.50  Male     No  Sun  Dinner     3              7.00
# 3         23.68  3.31  Male     No  Sun  Dinner     2             11.84
# 5         25.29  4.71  Male     No  Sun  Dinner     4              6.32
# 6          8.77  2.00  Male     No  Sun  Dinner     2              4.38
# ..          ...   ...   ...    ...  ...     ...   ...               ...
# 236       12.60  1.00  Male    Yes  Sat  Dinner     2              6.30
# 237       32.83  1.17  Male    Yes  Sat  Dinner     2             16.42
# 239       29.03  5.92  Male     No  Sat  Dinner     3              9.68
# 241       22.67  2.00  Male    Yes  Sat  Dinner     2             11.34
# 242       17.82  1.75  Male     No  Sat  Dinner     2              8.91
#
#              Payer Name         CC Number Payment ID
# ...

# %%
#multiple conditions 
# AND or & -> both are true 
# OR or | -> either one is true

# %%
(df['total_bill'] > 30) & (df['sex'] == 'Male')
# Out:
#      total_bill    tip   sex smoker   day    time  size  price_per_person
# 23        39.42   7.58  Male     No   Sat  Dinner     4              9.86  \
# 39        31.27   5.00  Male     No   Sat  Dinner     3             10.42
# 44        30.40   5.60  Male     No   Sun  Dinner     4              7.60
# 47        32.40   6.00  Male     No   Sun  Dinner     4              8.10
# 56        38.01   3.00  Male    Yes   Sat  Dinner     4              9.50
# 59        48.27   6.73  Male     No   Sat  Dinner     4             12.07
# 83        32.68   5.00  Male    Yes  Thur   Lunch     2             16.34
# 95        40.17   4.73  Male    Yes   Fri  Dinner     4             10.04
# 112       38.07   4.00  Male     No   Sun  Dinner     3             12.69
# 141       34.30   6.70  Male     No  Thur   Lunch     6              5.72
# 142       41.19   5.00  Male     No  Thur   Lunch     5              8.24
# 156       48.17   5.00  Male     No   Sun  Dinner     6              8.03
# ...

# %%
(df['total_bill'] > 30) | (df['sex'] == 'Male')
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 239     True
# 240    False
# 241     True
# 242     True
# 243    False
# Length: 244, dtype: bool

# %%
df[(df['total_bill'] > 30) & (df['sex'] == 'Male')]
# Out:
#      total_bill    tip   sex smoker   day    time  size  price_per_person
# 23        39.42   7.58  Male     No   Sat  Dinner     4              9.86  \
# 39        31.27   5.00  Male     No   Sat  Dinner     3             10.42
# 44        30.40   5.60  Male     No   Sun  Dinner     4              7.60
# 47        32.40   6.00  Male     No   Sun  Dinner     4              8.10
# 56        38.01   3.00  Male    Yes   Sat  Dinner     4              9.50
# 59        48.27   6.73  Male     No   Sat  Dinner     4             12.07
# 83        32.68   5.00  Male    Yes  Thur   Lunch     2             16.34
# 95        40.17   4.73  Male    Yes   Fri  Dinner     4             10.04
# 112       38.07   4.00  Male     No   Sun  Dinner     3             12.69
# 141       34.30   6.70  Male     No  Thur   Lunch     6              5.72
# 142       41.19   5.00  Male     No  Thur   Lunch     5              8.24
# 156       48.17   5.00  Male     No   Sun  Dinner     6              8.03
# ...

# %%
df[(df['day'] == 'Sun') | (df['day'] == 'Sat') | (df['day'] == 'Fri')]
# Out:
#      total_bill   tip     sex smoker  day    time  size  price_per_person
# 0         16.99  1.01  Female     No  Sun  Dinner     2              8.49  \
# 1         10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No  Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...  ...     ...   ...               ...
# 238       35.83  4.67  Female     No  Sat  Dinner     3             11.94
# 239       29.03  5.92    Male     No  Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No  Sat  Dinner     2              8.91
#
#              Payer Name         CC Number Payment ID
# ...

# %%
#instead of above
options = ['Sat', 'Sun', 'Fri']

# %%
df['day'].isin(options)
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 239     True
# 240     True
# 241     True
# 242     True
# 243    False
# Name: day, Length: 244, dtype: bool

# %%
df[(df['day'].isin(options))]
# Out:
#      total_bill   tip     sex smoker  day    time  size  price_per_person
# 0         16.99  1.01  Female     No  Sun  Dinner     2              8.49  \
# 1         10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No  Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...  ...     ...   ...               ...
# 238       35.83  4.67  Female     No  Sat  Dinner     3             11.94
# 239       29.03  5.92    Male     No  Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No  Sat  Dinner     2              8.91
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df[(df['day'].isin(['Sat', 'Sun', 'Fri']))]
# Out:
#      total_bill   tip     sex smoker  day    time  size  price_per_person
# 0         16.99  1.01  Female     No  Sun  Dinner     2              8.49  \
# 1         10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No  Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...  ...     ...   ...               ...
# 238       35.83  4.67  Female     No  Sat  Dinner     3             11.94
# 239       29.03  5.92    Male     No  Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No  Sat  Dinner     2              8.91
#
#              Payer Name         CC Number Payment ID
# ...

# %%
#apply Methods
df.info()
# note that CC number is an integer and cannot take last 4 digits of it just like that
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 21.1+ KB

# %%
str(123456789)[4:]
# Out:
# '56789'

# %%
str(123456789)[-4:]
# last 4 digits of integer
# Out:
# '6789'

# %%
def last_four (num):
    return str(num)[-4:]

# %%
last_four(123456789)
# Out:
# '6789'

# %%
#applying this function to df 
df['last_four'] = df['CC Number'].apply(last_four)

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49  \
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID last_four
# ...

# %%
df['total_bill'].mean()
# Out:
# 19.78594262295082

# %%
def yelp(price):
    if price < 10:
        return '$'
    elif 10 < price <30:
        return '$$'
    else:
        return '$$$'

# %%
df['yelp'] = df['total_bill'].apply(yelp)
df
# note that apply() function should return a single value only because its taking in single values
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49  \
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID last_four yelp
# ...

# %%
#lambda function 
df['total_bill'].apply(lambda num: num*3)
# Out:
# 0      50.97
# 1      31.02
# 2      63.03
# 3      71.04
# 4      73.77
#        ...
# 239    87.09
# 240    81.54
# 241    68.01
# 242    53.46
# 243    56.34
# Name: total_bill, Length: 244, dtype: float64

# %%
df['total_bill']*3
# Out:
# 0      50.97
# 1      31.02
# 2      63.03
# 3      71.04
# 4      73.77
#        ...
# 239    87.09
# 240    81.54
# 241    68.01
# 242    53.46
# 243    56.34
# Name: total_bill, Length: 244, dtype: float64

# %%
#using apply on multiple columns 
def tipquality(total_bill,tip):
    if tip/total_bill > 0.25:
        return 'Generous'
    else:
        return 'its meh...'

# %%
tipquality(17.99,2)
# Out:
# 'its meh...'

# %%
df[['total_bill','tip']].apply(lambda df: tipquality(df['total_bill'],df['tip']),axis=1)
#the axis parameter should be specified when you want to apply a function to a specific axis (i.e., row-wise or column-wise), and it should be left out when you want to apply the function to the entire DataFrame.
# Out:
# 0      its meh...
# 1      its meh...
# 2      its meh...
# 3      its meh...
# 4      its meh...
#           ...
# 239    its meh...
# 240    its meh...
# 241    its meh...
# 242    its meh...
# 243    its meh...
# Length: 244, dtype: object

# %%
np.vectorize(tipquality)(df['total_bill'],df['tip'])
# Out:
# array(['its meh...', 'its meh...', 'its meh...', 'its meh...',
#        'its meh...', 'its meh...', 'its meh...', 'its meh...',
#        'its meh...', 'its meh...', 'its meh...', 'its meh...',
#        'its meh...', 'its meh...', 'its meh...', 'its meh...',
#        'its meh...', 'its meh...', 'its meh...', 'its meh...',
#        'its meh...', 'its meh...', 'its meh...', 'its meh...',
#        'its meh...', 'its meh...', 'its meh...', 'its meh...',
#        'its meh...', 'its meh...', 'its meh...', 'its meh...',
#        'its meh...', 'its meh...', 'its meh...', 'its meh...',
#        'its meh...', 'its meh...', 'its meh...', 'its meh...',
#        'its meh...', 'its meh...', 'its meh...', 'its meh...',
#        'its meh...', 'its meh...', 'its meh...', 'its meh...',
#        'its meh...', 'its meh...', 'its meh...', 'Generous', 'its meh...',
#        'its meh...', 'its meh...', 'its meh...', 'its meh...',
#        'its meh...', 'its meh...', 'its meh...', 'its meh...',
# ...

# %%
np.vectorize(tipquality)(df['total_bill'],df['tip']).dtype
# Out:
# dtype('<U10')

# %%
import timeit
#this is to time how long it takes for a command or statement to run

# %%
setup = '''
import numpy as np 
import pandas as pd 
df = pd.read_csv('/Users/ada4sh/Documents/Study/Python/Python for ML and DScience/UNZIP_FOR_NOTEBOOKS_FINAL/03-Pandas/tips.csv')
def tipquality(total_bill,tip):
    if tip/total_bill > 0.25:
        return 'Generous'
    else:
        return 'its meh...'
'''

# %%
stmt1 = '''
df[['total_bill','tip']].apply(lambda df: tipquality(df['total_bill'],df['tip']),axis=1)
'''
stmt2 = '''
np.vectorize(tipquality)(df['total_bill'],df['tip'])
'''

# %%
timeit.timeit(setup=setup,stmt=stmt1,number=1000)
# Out:
# 1.24876799993217

# %%
timeit.timeit(setup=setup,stmt=stmt2,number=1000)
# Out:
# 0.1122424160130322

# %%
df = pd.read_csv('/Users/ada4sh/Documents/Study/Python/Python for ML and DScience/UNZIP_FOR_NOTEBOOKS_FINAL/03-Pandas/tips.csv')

# %%
#statistical info 
df.describe()
# Out:
#        total_bill         tip        size  price_per_person     CC Number
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    19.785943    2.998279    2.569672          7.888197  2.563496e+15
# std      8.902412    1.383638    0.951100          2.914234  2.369340e+15
# min      3.070000    1.000000    1.000000          2.880000  6.040679e+10
# 25%     13.347500    2.000000    2.000000          5.800000  3.040731e+13
# 50%     17.795000    2.900000    2.000000          7.255000  3.525318e+15
# 75%     24.127500    3.562500    3.000000          9.390000  4.553675e+15
# max     50.810000   10.000000    6.000000         20.270000  6.596454e+15

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 21.1+ KB

# %%
df.shape
# Out:
# (244, 11)

# %%
df.sort_values('tip')
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1              3.07  \
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2              6.30
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
# 111        7.25   1.00  Female     No   Sat  Dinner     1              7.25
# 0         16.99   1.01  Female     No   Sun  Dinner     2              8.49
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df.sort_values('tip',ascending=False)
#true is default
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94  \
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 0         16.99   1.01  Female     No   Sun  Dinner     2              8.49
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2              6.30
# 111        7.25   1.00  Female     No   Sat  Dinner     1              7.25
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1              3.07
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df.sort_values(['tip','size'])
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1              3.07  \
# 111        7.25   1.00  Female     No   Sat  Dinner     1              7.25
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2              6.30
# 0         16.99   1.01  Female     No   Sun  Dinner     2              8.49
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df['total_bill'].max()
# Out:
# 50.81

# %%
df['total_bill'].idxmax()
# Out:
# 170

# %%
df.iloc[170]
# Out:
# total_bill                     50.81
# tip                             10.0
# sex                             Male
# smoker                           Yes
# day                              Sat
# time                          Dinner
# size                               3
# price_per_person               16.94
# Payer Name             Gregory Clark
# CC Number           5473850968388236
# Payment ID                   Sat1954
# Name: 170, dtype: object

# %%
df.iloc[df['total_bill'].idxmin()]
# Out:
# total_bill                      3.07
# tip                              1.0
# sex                           Female
# smoker                           Yes
# day                              Sat
# time                          Dinner
# size                               1
# price_per_person                3.07
# Payer Name             Tiffany Brock
# CC Number           4359488526995267
# Payment ID                   Sat3455
# Name: 67, dtype: object

# %%
df.describe()
# Out:
#        total_bill         tip        size  price_per_person     CC Number
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    19.785943    2.998279    2.569672          7.888197  2.563496e+15
# std      8.902412    1.383638    0.951100          2.914234  2.369340e+15
# min      3.070000    1.000000    1.000000          2.880000  6.040679e+10
# 25%     13.347500    2.000000    2.000000          5.800000  3.040731e+13
# 50%     17.795000    2.900000    2.000000          7.255000  3.525318e+15
# 75%     24.127500    3.562500    3.000000          9.390000  4.553675e+15
# max     50.810000   10.000000    6.000000         20.270000  6.596454e+15

# %%
df.select_dtypes(include=['float64', 'int64']).corr()
# Out:
#                   total_bill       tip      size  price_per_person  CC Number
# total_bill          1.000000  0.675734  0.598315          0.647554   0.104576
# tip                 0.675734  1.000000  0.489299          0.347405   0.110857
# size                0.598315  0.489299  1.000000         -0.175359  -0.030239
# price_per_person    0.647554  0.347405 -0.175359          1.000000   0.135240
# CC Number           0.104576  0.110857 -0.030239          0.135240   1.000000

# %%
df['sex'].value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
df['day'].unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
df['day'].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
len(df['day'].unique())
# Out:
# 4

# %%
df['sex'].replace('Female','F')
# Out:
# 0         F
# 1      Male
# 2      Male
# 3      Male
# 4         F
#        ...
# 239    Male
# 240       F
# 241    Male
# 242    Male
# 243       F
# Name: sex, Length: 244, dtype: object

# %%
df['sex'].replace(['Female','Male'],['F','M'])
# Out:
# 0      F
# 1      M
# 2      M
# 3      M
# 4      F
#       ..
# 239    M
# 240    F
# 241    M
# 242    M
# 243    F
# Name: sex, Length: 244, dtype: object

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49  \
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
# if lots of items need replacing, using map() function, and this is done through dictionaries
sexmap = {'Female': 'F','Male':'M'}

# %%
df['sex'].map(sexmap)
# Out:
# 0      F
# 1      M
# 2      M
# 3      M
# 4      F
#       ..
# 239    M
# 240    F
# 241    M
# 242    M
# 243    F
# Name: sex, Length: 244, dtype: object

# %%
#duplicated rows
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240    False
# 241    False
# 242    False
# 243    False
# Length: 244, dtype: bool

# %%
test_df = pd.DataFrame([1,2,2,2],['a','b','c','d'])

# %%
test_df.duplicated()
# Out:
# a    False
# b    False
# c     True
# d     True
# dtype: bool

# %%
test_df.drop_duplicates()
# Out:
#    0
# a  1
# b  2

# %%
test_df1 = pd.DataFrame(['a','b','c','d'],[1,2,2,2])

# %%
test_df1.duplicated()
# Out:
# 1    False
# 2    False
# 2    False
# 2    False
# dtype: bool

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49  \
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df['total_bill'].between(10,20)
# Out:
# 0       True
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240    False
# 241    False
# 242     True
# 243     True
# Name: total_bill, Length: 244, dtype: bool

# %%
df['total_bill'].between(10,20).value_counts()
# Out:
# total_bill
# True     130
# False    114
# Name: count, dtype: int64

# %%
#to include the end points, inclusive can have 'both','left','right','neither'(both is default)
df['total_bill'].between(10,20,inclusive='both')
# Out:
# 0       True
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240    False
# 241    False
# 242     True
# 243     True
# Name: total_bill, Length: 244, dtype: bool

# %%
#sorting per column. eg: get top 10 tips (2 ways to do it)
df.sort_values('tip',ascending=False).iloc[:10]
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94  \
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# 214       28.17   6.50  Female    Yes   Sat  Dinner     3              9.39
# 183       23.17   6.50    Male    Yes   Sun  Dinner     4              5.79
# 47        32.40   6.00    Male     No   Sun  Dinner     4              8.10
# 239       29.03   5.92    Male     No   Sat  Dinner     3              9.68
# 88        24.71   5.85    Male     No  Thur   Lunch     2             12.36
#
#             Payer Name         CC Number Payment ID
# 170      Gregory Clark  5473850968388236    Sat1954
# ...

# %%
df.nlargest(10,'tip')
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94  \
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# 183       23.17   6.50    Male    Yes   Sun  Dinner     4              5.79
# 214       28.17   6.50  Female    Yes   Sat  Dinner     3              9.39
# 47        32.40   6.00    Male     No   Sun  Dinner     4              8.10
# 239       29.03   5.92    Male     No   Sat  Dinner     3              9.68
# 88        24.71   5.85    Male     No  Thur   Lunch     2             12.36
#
#             Payer Name         CC Number Payment ID
# 170      Gregory Clark  5473850968388236    Sat1954
# ...

# %%
df.nsmallest(10,'tip')
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1              3.07  \
# 92         5.75  1.00  Female    Yes   Fri  Dinner     2              2.88
# 111        7.25  1.00  Female     No   Sat  Dinner     1              7.25
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2              6.30
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 215       12.90  1.10  Female    Yes   Sat  Dinner     2              6.45
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2             16.42
# 75        10.51  1.25    Male     No   Sat  Dinner     2              5.26
# 135        8.51  1.25  Female     No  Thur   Lunch     2              4.26
# 235       10.07  1.25    Male     No   Sat  Dinner     2              5.04
#
#              Payer Name         CC Number Payment ID
# 67        Tiffany Brock  4359488526995267    Sat3455
# ...

# %%
#sampling by number of rows or fraction of df 
#sample 10 random rows
df.sample(10)
# Out:
#      total_bill   tip   sex smoker   day    time  size  price_per_person
# 90        28.97  3.00  Male    Yes   Fri  Dinner     2             14.48  \
# 189       23.10  4.00  Male    Yes   Sun  Dinner     3              7.70
# 78        22.76  3.00  Male     No  Thur   Lunch     2             11.38
# 241       22.67  2.00  Male    Yes   Sat  Dinner     2             11.34
# 177       14.48  2.00  Male    Yes   Sun  Dinner     2              7.24
# 55        19.49  3.51  Male     No   Sun  Dinner     2              9.74
# 13        18.43  3.00  Male     No   Sun  Dinner     4              4.61
# 224       13.42  1.58  Male    Yes   Fri   Lunch     2              6.71
# 208       24.27  2.03  Male    Yes   Sat  Dinner     2             12.14
# 160       21.50  3.50  Male     No   Sun  Dinner     4              5.38
#
#             Payer Name         CC Number Payment ID
# 90        Daniel Mason  3597456900644078    Fri4175
# 189    Richard Stevens  3560193117506187    Sun1821
# ...

# %%
#randomly sample 10% of rows
df.sample(frac=0.1)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84  \
# 74        14.73  2.20  Female     No   Sat  Dinner     2              7.36
# 84        15.98  2.03    Male     No  Thur   Lunch     2              7.99
# 57        26.41  1.50  Female     No   Sat  Dinner     2             13.20
# 100       11.35  2.50  Female    Yes   Fri  Dinner     2              5.68
# 31        18.35  2.50    Male     No   Sat  Dinner     4              4.59
# 195        7.56  1.44    Male     No  Thur   Lunch     2              3.78
# 154       19.77  2.00    Male     No   Sun  Dinner     4              4.94
# 165       24.52  3.48    Male     No   Sun  Dinner     3              8.17
# 209       12.76  2.23  Female    Yes   Sat  Dinner     2              6.38
# 35        24.06  3.60    Male     No   Sat  Dinner     3              8.02
# ...

# %%
#handling missing data 
#missing data or null values is shown as 'NaN', or 'pd.NaT' (not a timestamp)
#options: keep it, remove it, replace it

# %%
np.nan
# Out:
# nan

# %%
pd.NA

# %%
pd.NaT
# Out:
# NaT

# %%
np.nan == np.nan
# Out:
# False

# %%
np.nan is np.nan
# Out:
# True

# %%
# !ls
# Out:
# UNZIP_FOR_NOTEBOOKS_FINAL    py_ml_dl_udemy_pandas.ipynb
# py_ml_dl_udemy_1.ipynb       requirements.txt
# py_ml_dl_udemy_numpy_1.ipynb

# %%
# !pwd
# Out:
# /Users/ada4sh/Documents/Study/Python/Python for ML and DScience

# %%
# !ls UNZIP_FOR_NOTEBOOKS_FINAL
# Out:
# 01-Python-Crash-Course                  15-Random-Forests
# 02-Numpy                                16-Boosted-Trees
# 03-Pandas                               17-Supervised-Learning-Capstone-Project
# 04-Matplotlib                           18-Naive-Bayes-and-NLP
# 05-Seaborn                              19-Unsupervised-Learning-Overview
# 06-Capstone-Project                     20-Kmeans-Clustering
# 07-Overview-of-Machine-Learning         21-Hierarchal-Clustering
# 08-Linear-Regression-Models             21-Hierarchical-Clustering
# 09-Feature-Engineering                  22-DBSCAN
# 10-Cross-Val-and-LinReg-Project         23-PCA-Principal-Component-Analysis
# 11-Logistic-Regression-Models           24-Model-Deployment
# 12-K-Nearest-Neighbors                  DATA
# 13-Support-Vector-Machines              Pierian_Data_Logo.png
# 14-Decision-Trees

# %%
# !ls UNZIP_FOR_NOTEBOOKS_FINAL/03-Pandas
# Out:
# 00-Series.ipynb
# 01-DataFrames.ipynb
# 02-Conditional-Filtering.ipynb
# 03-Useful-Methods.ipynb
# 04-Missing-Data.ipynb
# 05-Groupby-Operations-and-MultiIndex.ipynb
# 06-Combining-DataFrames.ipynb
# 07-Text-Methods.ipynb
# 08-Time-Methods.ipynb
# 09-Inputs-and-Outputs.ipynb
# 10-Pivot-Tables.ipynb
# 11-Pandas-Project-Exercise .ipynb
# 12-Pandas-Project-Exercise-Solution.ipynb
# RetailSales_BeerWineLiquor.csv
# Sales_Funnel_CRM.csv
# __pycache__
# example.csv
# example.xlsx
# hotel_booking_data.csv
# movie_scores.csv
# mpg.csv
# my_excel_file.xlsx
# new_file.csv
# new_workbook.xlsx
# newfile.csv
# reshaping_pivot.png
# sample_table.html
# simple.html
# tips.csv

# %%
dfm = pd.read_csv('/Users/ada4sh/Documents/Study/Python/Python for ML and DScience/UNZIP_FOR_NOTEBOOKS_FINAL/03-Pandas/movie_scores.csv')

# %%
dfm.head()
# Out:
#   first_name last_name   age  sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0    m              8.0              10.0
# 1        NaN       NaN   NaN  NaN              NaN               NaN
# 2       Hugh   Jackman  51.0    m              NaN               NaN
# 3      Oprah   Winfrey  66.0    f              6.0               8.0
# 4       Emma     Stone  31.0    f              7.0               9.0

# %%
dfm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   first_name        4 non-null      object
#  1   last_name         4 non-null      object
#  2   age               4 non-null      float64
#  3   sex               4 non-null      object
#  4   pre_movie_score   3 non-null      float64
#  5   post_movie_score  3 non-null      float64
# dtypes: float64(3), object(3)
# memory usage: 372.0+ bytes

# %%
dfm.count()
# Out:
# first_name          4
# last_name           4
# age                 4
# sex                 4
# pre_movie_score     3
# post_movie_score    3
# dtype: int64

# %%
dfm.shape
# Out:
# (5, 6)

# %%
dfm.isnull()
# Out:
#    first_name  last_name    age    sex  pre_movie_score  post_movie_score
# 0       False      False  False  False            False             False
# 1        True       True   True   True             True              True
# 2       False      False  False  False             True              True
# 3       False      False  False  False            False             False
# 4       False      False  False  False            False             False

# %%
dfm.notnull()
# Out:
#    first_name  last_name    age    sex  pre_movie_score  post_movie_score
# 0        True       True   True   True             True              True
# 1       False      False  False  False            False             False
# 2        True       True   True   True            False             False
# 3        True       True   True   True             True              True
# 4        True       True   True   True             True              True

# %%
dfm['pre_movie_score'].notnull()
# Out:
# 0     True
# 1    False
# 2    False
# 3     True
# 4     True
# Name: pre_movie_score, dtype: bool

# %%
dfm[dfm['pre_movie_score'].notnull()]
# Out:
#   first_name last_name   age sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0   m              8.0              10.0
# 3      Oprah   Winfrey  66.0   f              6.0               8.0
# 4       Emma     Stone  31.0   f              7.0               9.0

# %%
dfm[(dfm['pre_movie_score'].isnull()) & (dfm['first_name'].notnull())]
# Out:
#   first_name last_name   age sex  pre_movie_score  post_movie_score
# 2       Hugh   Jackman  51.0   m              NaN               NaN

# %%
#keep data -- so far
#drop data
#fill data

# %%
#dropping data

# %%
help(dfm.dropna)
# notice the parameters thats are can be used or needed to drop null values
# Out:
# Help on method dropna in module pandas.core.frame:
#
# dropna(*, axis: 'Axis' = 0, how: 'AnyAll | NoDefault' = <no_default>, thresh: 'int | NoDefault' = <no_default>, subset: 'IndexLabel' = None, inplace: 'bool' = False, ignore_index: 'bool' = False) -> 'DataFrame | None' method of pandas.core.frame.DataFrame instance
#     Remove missing values.
#
#     See the :ref:`User Guide <missing_data>` for more on which values are
#     considered missing, and how to work with missing data.
#
#     Parameters
#     ----------
#     axis : {0 or 'index', 1 or 'columns'}, default 0
#         Determine if rows or columns which contain missing values are
#         removed.
#
#         * 0, or 'index' : Drop rows which contain missing values.
#         * 1, or 'columns' : Drop columns which contain missing value.
#
#         Pass tuple or list to drop on multiple axes.
#         Only a single axis is allowed.
#
#     how : {'any', 'all'}, default 'any'
# ...

# %%
dfm
# Out:
#   first_name last_name   age  sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0    m              8.0              10.0
# 1        NaN       NaN   NaN  NaN              NaN               NaN
# 2       Hugh   Jackman  51.0    m              NaN               NaN
# 3      Oprah   Winfrey  66.0    f              6.0               8.0
# 4       Emma     Stone  31.0    f              7.0               9.0

# %%
dfm.dropna()
# this dropped rows with any or all missing values
# Out:
#   first_name last_name   age sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0   m              8.0              10.0
# 3      Oprah   Winfrey  66.0   f              6.0               8.0
# 4       Emma     Stone  31.0   f              7.0               9.0

# %%
#dropping rows with atleast n number of non null values 
# nice way to drop rows with all null values (thresh = 1)
dfm.dropna(thresh=1)
# Out:
#   first_name last_name   age sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0   m              8.0              10.0
# 2       Hugh   Jackman  51.0   m              NaN               NaN
# 3      Oprah   Winfrey  66.0   f              6.0               8.0
# 4       Emma     Stone  31.0   f              7.0               9.0

# %%
dfm.dropna(thresh=3)
# Out:
#   first_name last_name   age sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0   m              8.0              10.0
# 2       Hugh   Jackman  51.0   m              NaN               NaN
# 3      Oprah   Winfrey  66.0   f              6.0               8.0
# 4       Emma     Stone  31.0   f              7.0               9.0

# %%
dfm.dropna(thresh=5)
# Out:
#   first_name last_name   age sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0   m              8.0              10.0
# 3      Oprah   Winfrey  66.0   f              6.0               8.0
# 4       Emma     Stone  31.0   f              7.0               9.0

# %%
dfm.dropna(axis=0)
# Out:
#   first_name last_name   age sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0   m              8.0              10.0
# 3      Oprah   Winfrey  66.0   f              6.0               8.0
# 4       Emma     Stone  31.0   f              7.0               9.0

# %%
#drop columns with any null values 
#here, every column has atleast one null value, so every column got dropped 
dfm.dropna(axis=1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
#remove rows that have null values in specific columns 
dfm.dropna(subset=['last_name'])
# Out:
#   first_name last_name   age sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0   m              8.0              10.0
# 2       Hugh   Jackman  51.0   m              NaN               NaN
# 3      Oprah   Winfrey  66.0   f              6.0               8.0
# 4       Emma     Stone  31.0   f              7.0               9.0

# %%
dfm['last_name'].dropna()
# Out:
# 0      Hanks
# 2    Jackman
# 3    Winfrey
# 4      Stone
# Name: last_name, dtype: object

# %%
#filling data

# %%
help(dfm.fillna)
# Out:
# Help on method fillna in module pandas.core.frame:
#
# fillna(value: 'Hashable | Mapping | Series | DataFrame' = None, *, method: 'FillnaOptions | None' = None, axis: 'Axis | None' = None, inplace: 'bool' = False, limit: 'int | None' = None, downcast: 'dict | None' = None) -> 'DataFrame | None' method of pandas.core.frame.DataFrame instance
#     Fill NA/NaN values using the specified method.
#
#     Parameters
#     ----------
#     value : scalar, dict, Series, or DataFrame
#         Value to use to fill holes (e.g. 0), alternately a
#         dict/Series/DataFrame of values specifying which value to use for
#         each index (for a Series) or column (for a DataFrame).  Values not
#         in the dict/Series/DataFrame will not be filled. This value cannot
#         be a list.
#     method : {'backfill', 'bfill', 'ffill', None}, default None
#         Method to use for filling holes in reindexed Series:
#
# ...

# %%
dfm.fillna('Null Value')
# this i snot a good idea, because string would be inserted into int or float columns as well
# Out:
#    first_name   last_name         age         sex pre_movie_score
# 0         Tom       Hanks        63.0           m             8.0  \
# 1  Null Value  Null Value  Null Value  Null Value      Null Value
# 2        Hugh     Jackman        51.0           m      Null Value
# 3       Oprah     Winfrey        66.0           f             6.0
# 4        Emma       Stone        31.0           f             7.0
#
#   post_movie_score
# 0             10.0
# 1       Null Value
# 2       Null Value
# 3              8.0
# 4              9.0

# %%
dfm['pre_movie_score'].fillna(0)
# Out:
# 0    8.0
# 1    0.0
# 2    0.0
# 3    6.0
# 4    7.0
# Name: pre_movie_score, dtype: float64

# %%
#instead of 0, you could give mean values

# %%
dfm['pre_movie_score'].mean()
# Out:
# 7.0

# %%
dfm['pre_movie_score'].fillna(dfm['pre_movie_score'].mean())
# Out:
# 0    8.0
# 1    7.0
# 2    7.0
# 3    6.0
# 4    7.0
# Name: pre_movie_score, dtype: float64

# %%
# dfm['pre_movie_score']=dfm['pre_movie_score'].fillna(dfm['pre_movie_score'].mean())
#this is to permanently fill null values.`

# %%
#to fill everything with mean value (numerical columns only)\
#dfm.fillna(dfm.mean()) -> this is not working like shown in the lecture 
dfm.select_dtypes(include=['float64', 'int64']).fillna(dfm.select_dtypes(include=['float64', 'int64']).mean())
# Out:
#      age  pre_movie_score  post_movie_score
# 0  63.00              8.0              10.0
# 1  52.75              7.0               9.0
# 2  51.00              7.0               9.0
# 3  66.00              6.0               8.0
# 4  31.00              7.0               9.0

# %%
help(dfm.interpolate)
# Out:
# Help on method interpolate in module pandas.core.frame:
#
# interpolate(method: 'str' = 'linear', *, axis: 'Axis' = 0, limit: 'int | None' = None, inplace: 'bool' = False, limit_direction: 'str | None' = None, limit_area: 'str | None' = None, downcast: 'str | None' = None, **kwargs) -> 'DataFrame | None' method of pandas.core.frame.DataFrame instance
#     Fill NaN values using an interpolation method.
#
#     Please note that only ``method='linear'`` is supported for
#     DataFrame/Series with a MultiIndex.
#
#     Parameters
#     ----------
#     method : str, default 'linear'
#         Interpolation technique to use. One of:
#
#         * 'linear': Ignore the index and treat the values as equally
#           spaced. This is the only method supported on MultiIndexes.
#         * 'time': Works on daily and higher resolution data to interpolate
#           given length of interval.
#         * 'index', 'values': use the actual numerical values of the index.
# ...

# %%
dfm.interpolate()
# Out:
#   first_name last_name   age  sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0    m         8.000000         10.000000
# 1        NaN       NaN  57.0  NaN         7.333333          9.333333
# 2       Hugh   Jackman  51.0    m         6.666667          8.666667
# 3      Oprah   Winfrey  66.0    f         6.000000          8.000000
# 4       Emma     Stone  31.0    f         7.000000          9.000000

# %%
# groupby

# %%
dfc = pd.read_csv('/Users/ada4sh/Documents/Study/Python/Python for ML and DScience/UNZIP_FOR_NOTEBOOKS_FINAL/03-Pandas/mpg.csv')

# %%
dfc.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year
# 0  18.0          8         307.0        130    3504          12.0          70  \
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
dfc['model_year'].value_counts()
# Out:
# model_year
# 73    40
# 78    36
# 76    34
# 82    31
# 75    30
# 70    29
# 79    29
# 80    29
# 81    29
# 71    28
# 72    28
# 77    28
# 74    27
# Name: count, dtype: int64

# %%
#groupby() is considered lazy, as it will require anotehr function that does somethinf with the grouped data

# %%
dfc.groupby('model_year').value_counts()
# Out:
# model_year  mpg   cylinders  displacement  horsepower  weight  acceleration  origin  name
# 70          9.0   8          304.0         193         4732    18.5          1       hi 1200d              1
#             10.0  8          307.0         200         4376    15.0          1       chevy c20             1
#             25.0  4          104.0         95          2375    17.5          2       saab 99e              1
#             24.0  4          107.0         90          2430    14.5          2       audi 100 ls           1
#             22.0  6          198.0         95          2833    15.5          1       plymouth duster       1
#                                                                                                           ..
# 82          31.0  4          91.0          68          1970    17.6          3       mazda glc custom      1
#             29.0  4          135.0         84          2525    16.0          1       dodge aries se        1
# ...

# %%
dfc.groupby('model_year').mean('mpg')
# Out:
#                   mpg  cylinders  displacement       weight  acceleration
# model_year
# 70          17.689655   6.758621    281.413793  3372.793103     12.948276  \
# 71          21.250000   5.571429    209.750000  2995.428571     15.142857
# 72          18.714286   5.821429    218.375000  3237.714286     15.125000
# 73          17.100000   6.375000    256.875000  3419.025000     14.312500
# 74          22.703704   5.259259    171.740741  2877.925926     16.203704
# 75          20.266667   5.600000    205.533333  3176.800000     16.050000
# 76          21.573529   5.647059    197.794118  3078.735294     15.941176
# 77          23.375000   5.464286    191.392857  2997.357143     15.435714
# 78          24.061111   5.361111    177.805556  2861.805556     15.805556
# 79          25.093103   5.827586    206.689655  3055.344828     15.813793
# 80          33.696552   4.137931    115.827586  2436.655172     16.934483
# ...

# %%
dfc.select_dtypes(include=['float64','int64']).groupby(['model_year', 'cylinders']).mean()
# Out:
#                             mpg  displacement       weight  acceleration
# model_year cylinders
# 70         4          25.285714    107.000000  2292.571429     16.000000  \
#            6          20.500000    199.000000  2710.500000     15.500000
#            8          14.111111    367.555556  3940.055556     11.194444
# 71         4          27.461538    101.846154  2056.384615     16.961538
#            6          18.000000    243.375000  3171.875000     14.750000
#            8          13.428571    371.714286  4537.714286     12.214286
# 72         3          19.000000     70.000000  2330.000000     13.500000
#            4          23.428571    111.535714  2382.642857     17.214286
#            8          13.615385    344.846154  4228.384615     13.000000
# 73         3          18.000000     70.000000  2124.000000     13.500000
#            4          22.727273    109.272727  2338.090909     17.136364
# ...

# %%
dfc.select_dtypes(include=['float64','int64']).groupby(['model_year', 'cylinders']).mean().index
#this is called a multi-level index
# Out:
# MultiIndex([(70, 4),
#             (70, 6),
#             (70, 8),
#             (71, 4),
#             (71, 6),
#             (71, 8),
#             (72, 3),
#             (72, 4),
#             (72, 8),
#             (73, 3),
#             (73, 4),
#             (73, 6),
#             (73, 8),
#             (74, 4),
#             (74, 6),
#             (74, 8),
#             (75, 4),
#             (75, 6),
#             (75, 8),
#             (76, 4),
#             (76, 6),
#             (76, 8),
#             (77, 3),
#             (77, 4),
#             (77, 6),
#             (77, 8),
#             (78, 4),
#             (78, 5),
#             (78, 6),
#             (78, 8),
#             (79, 4),
#             (79, 5),
#             (79, 6),
#             (79, 8),
#             (80, 3),
#             (80, 4),
#             (80, 5),
#             (80, 6),
#             (81, 4),
#             (81, 6),
#             (81, 8),
#             (82, 4),
#             (82, 6)],
# ...

# %%
dfc.groupby('model_year').describe().transpose()
# Out:
# model_year                   70           71           72           73
# mpg          count    29.000000    28.000000    28.000000    40.000000  \
#              mean     17.689655    21.250000    18.714286    17.100000
#              std       5.339231     6.591942     5.435529     4.700245
#              min       9.000000    12.000000    11.000000    11.000000
#              25%      14.000000    15.500000    13.750000    13.000000
#              50%      16.000000    19.000000    18.500000    16.000000
#              75%      22.000000    27.000000    23.000000    20.000000
#              max      27.000000    35.000000    28.000000    29.000000
# cylinders    count    29.000000    28.000000    28.000000    40.000000
#              mean      6.758621     5.571429     5.821429     6.375000
#              std       1.724926     1.665079     2.073708     1.807215
#              min       4.000000     4.000000     3.000000     3.000000
# ...

# %%
year_cyl = dfc.select_dtypes(include=['float64','int64']).groupby(['model_year','cylinders']).mean()
year_cyl
# Out:
#                             mpg  displacement       weight  acceleration
# model_year cylinders
# 70         4          25.285714    107.000000  2292.571429     16.000000  \
#            6          20.500000    199.000000  2710.500000     15.500000
#            8          14.111111    367.555556  3940.055556     11.194444
# 71         4          27.461538    101.846154  2056.384615     16.961538
#            6          18.000000    243.375000  3171.875000     14.750000
#            8          13.428571    371.714286  4537.714286     12.214286
# 72         3          19.000000     70.000000  2330.000000     13.500000
#            4          23.428571    111.535714  2382.642857     17.214286
#            8          13.615385    344.846154  4228.384615     13.000000
# 73         3          18.000000     70.000000  2124.000000     13.500000
#            4          22.727273    109.272727  2338.090909     17.136364
# ...

# %%
year_cyl.index
# Out:
# MultiIndex([(70, 4),
#             (70, 6),
#             (70, 8),
#             (71, 4),
#             (71, 6),
#             (71, 8),
#             (72, 3),
#             (72, 4),
#             (72, 8),
#             (73, 3),
#             (73, 4),
#             (73, 6),
#             (73, 8),
#             (74, 4),
#             (74, 6),
#             (74, 8),
#             (75, 4),
#             (75, 6),
#             (75, 8),
#             (76, 4),
#             (76, 6),
#             (76, 8),
#             (77, 3),
#             (77, 4),
#             (77, 6),
#             (77, 8),
#             (78, 4),
#             (78, 5),
#             (78, 6),
#             (78, 8),
#             (79, 4),
#             (79, 5),
#             (79, 6),
#             (79, 8),
#             (80, 3),
#             (80, 4),
#             (80, 5),
#             (80, 6),
#             (81, 4),
#             (81, 6),
#             (81, 8),
#             (82, 4),
#             (82, 6)],
# ...

# %%
year_cyl.index.names
# Out:
# FrozenList(['model_year', 'cylinders'])

# %%
year_cyl.index.levels
# Out:
# FrozenList([[70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82], [3, 4, 5, 6, 8]])

# %%
year_cyl.loc[70]
# Out:
#                  mpg  displacement       weight  acceleration    origin
# cylinders
# 4          25.285714    107.000000  2292.571429     16.000000  2.285714
# 6          20.500000    199.000000  2710.500000     15.500000  1.000000
# 8          14.111111    367.555556  3940.055556     11.194444  1.000000

# %%
year_cyl.loc[[70,80]]
# Out:
#                             mpg  displacement       weight  acceleration
# model_year cylinders
# 70         4          25.285714    107.000000  2292.571429     16.000000  \
#            6          20.500000    199.000000  2710.500000     15.500000
#            8          14.111111    367.555556  3940.055556     11.194444
# 80         3          23.700000     70.000000  2420.000000     12.500000
#            4          34.612000    111.000000  2360.080000     17.144000
#            5          36.400000    121.000000  2950.000000     19.900000
#            6          25.900000    196.500000  3145.500000     15.050000
#
#                         origin
# model_year cylinders
# 70         4          2.285714
#            6          1.000000
#            8          1.000000
# 80         3          3.000000
#            4          2.200000
#            5          2.000000
#            6          2.000000

# %%
year_cyl.loc[[(70,4),(80,4)]]
# Out:
#                             mpg  displacement       weight  acceleration
# model_year cylinders
# 70         4          25.285714         107.0  2292.571429        16.000  \
# 80         4          34.612000         111.0  2360.080000        17.144
#
#                         origin
# model_year cylinders
# 70         4          2.285714
# 80         4          2.200000

# %%
year_cyl.loc[(70,4)]
# Out:
# mpg               25.285714
# displacement     107.000000
# weight          2292.571429
# acceleration      16.000000
# origin             2.285714
# Name: (70, 4), dtype: float64

# %%
#cross-sections of series or dfs

# %%
#with loc, i cannot get the data for all 4 cylinders in all the years, hence, cross section 
#cross sections only take 1 key (outside index)
year_cyl.xs(key=70)
# Out:
#                  mpg  displacement       weight  acceleration    origin
# cylinders
# 4          25.285714    107.000000  2292.571429     16.000000  2.285714
# 6          20.500000    199.000000  2710.500000     15.500000  1.000000
# 8          14.111111    367.555556  3940.055556     11.194444  1.000000

# %%
year_cyl.xs(key=70,level='model_year')
# Out:
#                  mpg  displacement       weight  acceleration    origin
# cylinders
# 4          25.285714    107.000000  2292.571429     16.000000  2.285714
# 6          20.500000    199.000000  2710.500000     15.500000  1.000000
# 8          14.111111    367.555556  3940.055556     11.194444  1.000000

# %%
year_cyl.xs(key=4,level='cylinders')
# Out:
#                   mpg  displacement       weight  acceleration    origin
# model_year
# 70          25.285714    107.000000  2292.571429     16.000000  2.285714
# 71          27.461538    101.846154  2056.384615     16.961538  1.923077
# 72          23.428571    111.535714  2382.642857     17.214286  1.928571
# 73          22.727273    109.272727  2338.090909     17.136364  2.000000
# 74          27.800000     96.533333  2151.466667     16.400000  2.200000
# 75          25.250000    114.833333  2489.250000     15.833333  2.166667
# 76          26.766667    106.333333  2306.600000     16.866667  1.866667
# 77          29.107143    106.500000  2205.071429     16.064286  1.857143
# 78          29.576471    112.117647  2296.764706     16.282353  2.117647
# 79          31.525000    113.583333  2357.583333     15.991667  1.583333
# 80          34.612000    111.000000  2360.080000     17.144000  2.200000
# 81          32.814286    108.857143  2275.476190     16.466667  2.095238
# ...

# %%
#level basically is what the key means. we have two levels in this example, model_year and cylinders (outside and inside indexes resp)

# %%
## this did NOT WORK:> year_cyl.xs(key=4)
# in order to get means of 6 and 8 cylinders, instead of filtering after groupby (like we just did for 4), 
# best practice is to first filter > groupby() > aggregate
dfc[dfc['cylinders'].isin([6,8])].select_dtypes(include=['float64','int64']).groupby(['model_year','cylinders']).mean()
# Out:
#                             mpg  displacement       weight  acceleration
# model_year cylinders
# 70         6          20.500000    199.000000  2710.500000     15.500000  \
#            8          14.111111    367.555556  3940.055556     11.194444
# 71         6          18.000000    243.375000  3171.875000     14.750000
#            8          13.428571    371.714286  4537.714286     12.214286
# 72         8          13.615385    344.846154  4228.384615     13.000000
# 73         6          19.000000    212.250000  2917.125000     15.687500
#            8          13.200000    365.250000  4279.050000     12.250000
# 74         6          17.857143    230.428571  3320.000000     16.857143
#            8          14.200000    315.200000  4438.400000     14.700000
# 75         6          17.583333    233.750000  3398.333333     17.708333
#            8          15.666667    330.500000  4108.833333     13.166667
# ...

# %%
#swapping outside and insie levels 
year_cyl.swaplevel()
# Out:
#                             mpg  displacement       weight  acceleration
# cylinders model_year
# 4         70          25.285714    107.000000  2292.571429     16.000000  \
# 6         70          20.500000    199.000000  2710.500000     15.500000
# 8         70          14.111111    367.555556  3940.055556     11.194444
# 4         71          27.461538    101.846154  2056.384615     16.961538
# 6         71          18.000000    243.375000  3171.875000     14.750000
# 8         71          13.428571    371.714286  4537.714286     12.214286
# 3         72          19.000000     70.000000  2330.000000     13.500000
# 4         72          23.428571    111.535714  2382.642857     17.214286
# 8         72          13.615385    344.846154  4228.384615     13.000000
# 3         73          18.000000     70.000000  2124.000000     13.500000
# 4         73          22.727273    109.272727  2338.090909     17.136364
# ...

# %%
year_cyl.swaplevel().loc[[6,8]]
# I guess you can filter with swap levels
# Out:
#                             mpg  displacement       weight  acceleration
# cylinders model_year
# 6         70          20.500000    199.000000  2710.500000     15.500000  \
#           71          18.000000    243.375000  3171.875000     14.750000
#           73          19.000000    212.250000  2917.125000     15.687500
#           74          17.857143    230.428571  3320.000000     16.857143
#           75          17.583333    233.750000  3398.333333     17.708333
#           76          20.000000    221.400000  3349.600000     17.000000
#           77          19.500000    220.400000  3383.000000     16.900000
#           78          19.066667    213.250000  3314.166667     16.391667
#           79          22.950000    205.666667  3025.833333     15.433333
#           80          25.900000    196.500000  3145.500000     15.050000
#           81          23.428571    184.000000  3093.571429     15.442857
# ...

# %%
#sorting
year_cyl.sort_values('model_year',ascending=False)
# Out:
#                             mpg  displacement       weight  acceleration
# model_year cylinders
# 82         6          28.333333    225.000000  2931.666667     16.033333  \
#            4          32.071429    118.571429  2402.321429     16.703571
# 81         8          26.600000    350.000000  3725.000000     19.000000
#            6          23.428571    184.000000  3093.571429     15.442857
#            4          32.814286    108.857143  2275.476190     16.466667
# 80         6          25.900000    196.500000  3145.500000     15.050000
#            5          36.400000    121.000000  2950.000000     19.900000
#            4          34.612000    111.000000  2360.080000     17.144000
#            3          23.700000     70.000000  2420.000000     12.500000
# 79         5          25.400000    183.000000  3530.000000     20.100000
#            4          31.525000    113.583333  2357.583333     15.991667
# ...

# %%
year_cyl.sort_values('cylinders',ascending=False)
# Out:
#                             mpg  displacement       weight  acceleration
# model_year cylinders
# 76         8          14.666667    324.000000  4064.666667     13.222222  \
# 77         8          16.000000    335.750000  4177.500000     13.662500
# 70         8          14.111111    367.555556  3940.055556     11.194444
# 81         8          26.600000    350.000000  3725.000000     19.000000
# 71         8          13.428571    371.714286  4537.714286     12.214286
# 74         8          14.200000    315.200000  4438.400000     14.700000
# 79         8          18.630000    321.400000  3862.900000     15.400000
# 72         8          13.615385    344.846154  4228.384615     13.000000
# 75         8          15.666667    330.500000  4108.833333     13.166667
# 78         8          19.050000    300.833333  3563.333333     13.266667
# 73         8          13.200000    365.250000  4279.050000     12.250000
# ...

# %%
# OR, better way which sorts both levels 
#here, sorting cylinders, and tyhen model year, whereas above, its just cylinders
year_cyl.sort_index(level='cylinders',ascending=False)
# Out:
#                             mpg  displacement       weight  acceleration
# model_year cylinders
# 81         8          26.600000    350.000000  3725.000000     19.000000  \
# 79         8          18.630000    321.400000  3862.900000     15.400000
# 78         8          19.050000    300.833333  3563.333333     13.266667
# 77         8          16.000000    335.750000  4177.500000     13.662500
# 76         8          14.666667    324.000000  4064.666667     13.222222
# 75         8          15.666667    330.500000  4108.833333     13.166667
# 74         8          14.200000    315.200000  4438.400000     14.700000
# 73         8          13.200000    365.250000  4279.050000     12.250000
# 72         8          13.615385    344.846154  4228.384615     13.000000
# 71         8          13.428571    371.714286  4537.714286     12.214286
# 70         8          14.111111    367.555556  3940.055556     11.194444
# ...

# %%
year_cyl.sort_index(level='model_year', ascending=False)
# Out:
#                             mpg  displacement       weight  acceleration
# model_year cylinders
# 82         6          28.333333    225.000000  2931.666667     16.033333  \
#            4          32.071429    118.571429  2402.321429     16.703571
# 81         8          26.600000    350.000000  3725.000000     19.000000
#            6          23.428571    184.000000  3093.571429     15.442857
#            4          32.814286    108.857143  2275.476190     16.466667
# 80         6          25.900000    196.500000  3145.500000     15.050000
#            5          36.400000    121.000000  2950.000000     19.900000
#            4          34.612000    111.000000  2360.080000     17.144000
#            3          23.700000     70.000000  2420.000000     12.500000
# 79         8          18.630000    321.400000  3862.900000     15.400000
#            6          22.950000    205.666667  3025.833333     15.433333
# ...

# %%
dfc.select_dtypes(include=['int64','float64']).agg(['mean','std'])
# Out:
#             mpg  cylinders  displacement       weight  acceleration
# mean  23.514573   5.454774    193.425879  2970.424623     15.568090  \
# std    7.815984   1.701004    104.269838   846.841774      2.757689
#
#       model_year    origin
# mean   76.010050  1.572864
# std     3.697627  0.802055

# %%
dfc.select_dtypes(include=['int64','float64']).agg(['mean','std'])['mpg']
# Out:
# mean    23.514573
# std      7.815984
# Name: mpg, dtype: float64

# %%
# you can get specific aggregates for specific columns (below) or full df (above) and can represent as a list for the entire dataframe as above, or as dictionary below
dfc.agg({'mpg':['min','max','mean'],'cylinders':['min','max'],'displacement':'std'})
# Out:
#             mpg  cylinders  displacement
# min    9.000000        3.0           NaN
# max   46.600000        8.0           NaN
# mean  23.514573        NaN           NaN
# std         NaN        NaN    104.269838

# %%
# Concatenation 
# Pasting two columns from two df together with similar columns or similar rows

# %%
one = pd.DataFrame({'A':['A0','A1','A2','A3'],'B':['B0','B1','B2','B3']})

# %%
two = pd.DataFrame({'C':['C0','C1','C2','C3'],'D':['D0','D1','D2','D3']})

# %%
two
# Out:
#     C   D
# 0  C0  D0
# 1  C1  D1
# 2  C2  D2
# 3  C3  D3

# %%
#concatinating along the columns, order matters 
pd.concat([one,two],axis=1)
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
#concatinating along rows 
pd.concat([one,two],axis=0)
# Out:
#      A    B    C    D
# 0   A0   B0  NaN  NaN
# 1   A1   B1  NaN  NaN
# 2   A2   B2  NaN  NaN
# 3   A3   B3  NaN  NaN
# 0  NaN  NaN   C0   D0
# 1  NaN  NaN   C1   D1
# 2  NaN  NaN   C2   D2
# 3  NaN  NaN   C3   D3

# %%
pd.concat([one,two])
#default is axis=0
# Out:
#      A    B    C    D
# 0   A0   B0  NaN  NaN
# 1   A1   B1  NaN  NaN
# 2   A2   B2  NaN  NaN
# 3   A3   B3  NaN  NaN
# 0  NaN  NaN   C0   D0
# 1  NaN  NaN   C1   D1
# 2  NaN  NaN   C2   D2
# 3  NaN  NaN   C3   D3

# %%
#another way to concat by rows, if C, D columns are the same as A, B but named differently, then rename>concat
two.columns=one.columns

# %%
two
# Out:
#     A   B
# 0  C0  D0
# 1  C1  D1
# 2  C2  D2
# 3  C3  D3

# %%
pd.concat([one,two],axis=0)
#no null values in this case
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1
# 2  A2  B2
# 3  A3  B3
# 0  C0  D0
# 1  C1  D1
# 2  C2  D2
# 3  C3  D3

# %%
# to reset the index: 
mydf = pd.concat([one,two],axis=0)

# %%
mydf.index
# Out:
# Index([0, 1, 2, 3, 0, 1, 2, 3], dtype='int64')

# %%
mydf.index=range(len(mydf))

# %%
mydf
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1
# 2  A2  B2
# 3  A3  B3
# 4  C0  D0
# 5  C1  D1
# 6  C2  D2
# 7  C3  D3

# %%
#inner,left,right,outer merge 
registrations = pd.DataFrame({'reg_id':[1,2,3,4],'name':['Andrew','Bobo','Claire','David']})
logins = pd.DataFrame({'log_id':[1,2,3,4],'name':['Xavier','Andrew','Yolanda','Bobo']})

# %%
registrations
# Out:
#    reg_id    name
# 0       1  Andrew
# 1       2    Bobo
# 2       3  Claire
# 3       4   David

# %%
logins
# Out:
#    log_id     name
# 0       1   Xavier
# 1       2   Andrew
# 2       3  Yolanda
# 3       4     Bobo

# %%
pd.merge(registrations,logins,how='inner',on='name')
# Out:
#    reg_id    name  log_id
# 0       1  Andrew       2
# 1       2    Bobo       4

# %%
pd.merge(logins,registrations,how='inner',on='name')
# order does not matter for inner, data will be the same except for column order
# Out:
#    log_id    name  reg_id
# 0       2  Andrew       1
# 1       4    Bobo       2

# %%
pd.merge(registrations,logins,how='left',on='name')
# Out:
#    reg_id    name  log_id
# 0       1  Andrew     2.0
# 1       2    Bobo     4.0
# 2       3  Claire     NaN
# 3       4   David     NaN

# %%
pd.merge(registrations,logins,how='right',on='name')
# Out:
#    reg_id     name  log_id
# 0     NaN   Xavier       1
# 1     1.0   Andrew       2
# 2     NaN  Yolanda       3
# 3     2.0     Bobo       4

# %%
#outer considers all the values (full set)-> df order doesnt matter 
pd.merge(registrations,logins,how='outer',on='name')
# Out:
#    reg_id     name  log_id
# 0     1.0   Andrew     2.0
# 1     2.0     Bobo     4.0
# 2     3.0   Claire     NaN
# 3     4.0    David     NaN
# 4     NaN   Xavier     1.0
# 5     NaN  Yolanda     3.0

# %%
#'on' is simple if both. df have same column name, or you can merge or join based on index or column name for each df 
#left_on, right_on, left_index and right_index (bool)
logins
# Out:
#    log_id     name
# 0       1   Xavier
# 1       2   Andrew
# 2       3  Yolanda
# 3       4     Bobo

# %%
registrations.columns=['reg_id','reg_name']

# %%
registrations
# Out:
#    reg_id reg_name
# 0       1   Andrew
# 1       2     Bobo
# 2       3   Claire
# 3       4    David

# %%
#pd.merge(registrations,logins,left_index=True, right_on='name',how='inner') -> did not work cuz index-> int, name-> str
pd.merge(registrations,logins,left_on='reg_name', right_on='name',how='inner')
# Out:
#    reg_id reg_name  log_id    name
# 0       1   Andrew       2  Andrew
# 1       2     Bobo       4    Bobo

# %%
pd.merge(registrations,logins,left_on='reg_name', right_on='name',how='inner').drop('name',axis=1)
# Out:
#    reg_id reg_name  log_id
# 0       1   Andrew       2
# 1       2     Bobo       4

# %%
pd.merge(registrations,logins,left_index=True,right_index=True,how='inner')
# Out:
#    reg_id reg_name  log_id     name
# 0       1   Andrew       1   Xavier
# 1       2     Bobo       2   Andrew
# 2       3   Claire       3  Yolanda
# 3       4    David       4     Bobo

# %%
registrations=registrations.set_index('reg_name')

# %%
registrations
# Out:
#           reg_id
# reg_name
# Andrew         1
# Bobo           2
# Claire         3
# David          4

# %%
pd.merge(registrations,logins,left_index=True,right_on='name',how='inner')
# Out:
#    reg_id  log_id    name
# 1       1       2  Andrew
# 3       2       4    Bobo

# %%
registrations=registrations.set_index('index')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[194], line 1
# ----> 1 registrations=registrations.set_index('index')
#
# File ~/opt/anaconda3/envs/python_udemy_ml_dl_env/lib/python3.11/site-packages/pandas/core/frame.py:5867, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    5864                 missing.append(col)
#    5866 if missing:
# -> 5867     raise KeyError(f"None of {missing} are in the columns")
#    5869 if inplace:
#    5870     frame = self
#
# KeyError: "None of ['index'] are in the columns"

# %%
registrations.columns=['name','id']

# %%
registrations
# Out:
#          name  reg_id
# index
# 0      Andrew       1
# 1        Bobo       2
# 2      Claire       3
# 3       David       4

# %%
logins.columns=['id','name']

# %%
logins
# Out:
#    id     name
# 0   1   Xavier
# 1   2   Andrew
# 2   3  Yolanda
# 3   4     Bobo

# %%
help(pd.merge)
# Out:
# Help on function merge in module pandas.core.reshape.merge:
#
# merge(left: 'DataFrame | Series', right: 'DataFrame | Series', how: 'MergeHow' = 'inner', on: 'IndexLabel | None' = None, left_on: 'IndexLabel | None' = None, right_on: 'IndexLabel | None' = None, left_index: 'bool' = False, right_index: 'bool' = False, sort: 'bool' = False, suffixes: 'Suffixes' = ('_x', '_y'), copy: 'bool | None' = None, indicator: 'str | bool' = False, validate: 'str | None' = None) -> 'DataFrame'
#     Merge DataFrame or named Series objects with a database-style join.
#
#     A named Series object is treated as a DataFrame with a single named column.
#
#     The join is done on columns or indexes. If joining columns on
#     columns, the DataFrame indexes *will be ignored*. Otherwise if joining indexes
#     on indexes or indexes on a column or columns, the index will be passed on.
#     When performing a cross merge, no column specifications to merge on are
#     allowed.
#
#     .. warning::
#
# ...

# %%
#adding suffixes
pd.merge(registrations,logins,how='inner',on='name',suffixes=("_reg","_log"))
# Out:
#      name  id_reg  id_log
# 0  Andrew       1       2
# 1    Bobo       2       4

# %%
#note that, the suffixes are only added when the non-joining columns of two dfs have same names.

# %%
#string data text methods

# %%
email='adarsh@email.com'

# %%
email.split('@')
# Out:
# ['adarsh', 'email.com']

# %%
email.split('@')[0]
# Out:
# 'adarsh'

# %%
names=['Nikhi','Narsi', 'Dhanu','Kanna','4']

# %%
type(names)
# Out:
# list

# %%
names=pd.Series(names)

# %%
names.dtype
# Out:
# dtype('O')

# %%
names.str.isdigit()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool

# %%
names.str.isnumeric()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool

# %%
names.str.upper()
# Out:
# 0    NIKHI
# 1    NARSI
# 2    DHANU
# 3    KANNA
# 4        4
# dtype: object

# %%
names.str.lower()
# Out:
# 0    nikhi
# 1    narsi
# 2    dhanu
# 3    kanna
# 4        4
# dtype: object

# %%
tech_names=['GOOGL,APPL,MSFT','CHS,JPMG,HUNT']

# %%
stocks=pd.Series(tech_names)

# %%
stocks
# Out:
# 0    GOOGL,APPL,MSFT
# 1      CHS,JPMG,HUNT
# dtype: object

# %%
stocks[0][0]
# Out:
# 'G'

# %%
stocks.str.split(',')
# Out:
# 0    [GOOGL, APPL, MSFT]
# 1      [CHS, JPMG, HUNT]
# dtype: object

# %%
stocks.str.split(',')[0][0]
# Out:
# 'GOOGL'

# %%
stocks.str.split(',',expand=True)
# Out:
#        0     1     2
# 0  GOOGL  APPL  MSFT
# 1    CHS  JPMG  HUNT

# %%
stocks.str.split(',',expand=True)[0]
# Out:
# 0    GOOGL
# 1      CHS
# Name: 0, dtype: object

# %%
messy_names=pd.Series(['   adarsh','  nik;hi ','nar$i','   dhannu   '])

# %%
messy_names
# Out:
# 0          adarsh
# 1         nik;hi
# 2           nar$i
# 3       dhannu
# dtype: object

# %%
messy_names.str.strip().str.replace(';','').str.replace('$','s').str.capitalize()
#note that for every string operation, str.<function>() is required
# Out:
# 0    Adarsh
# 1     Nikhi
# 2     Narsi
# 3    Dhannu
# dtype: object

# %%
# OR use apply()
def Cleanup(name):
    name = name.strip()
    name = name.replace(';','')
    name = name.replace('$','s')
    name = name.capitalize()
    return name

# %%
messy_names.apply(Cleanup)
# Out:
# 0    Adarsh
# 1     Nikhi
# 2     Narsi
# 3    Dhannu
# dtype: object

# %%
np.vectorize(Cleanup)(messy_names)
#np.vectorize(<function>)(<Series_name>)
# Out:
# array(['Adarsh', 'Nikhi', 'Narsi', 'Dhannu'], dtype='<U6')

# %%
import timeit as tm

# %%
setup = '''
import numpy as np 
import pandas as pd
messy_names=pd.Series(['   adarsh','  nik;hi ','nar$i','   dhannu   '])
def Cleanup(name):
    name = name.strip()
    name = name.replace(';','')
    name = name.replace('$','s')
    name = name.capitalize()
    return name
'''

# %%
stmt1 = 'messy_names.str.strip().str.replace(";","").str.replace("$","s").str.capitalize()'
stmt2 = 'messy_names.apply(Cleanup)'
stmt3 = 'np.vectorize(Cleanup)(messy_names)'
# note: got error with $ sign, put in "$" so that it knows its a character

# %%
tm.timeit(setup=setup,stmt=stmt1,number=1000)
# Out:
# 0.2220536659588106

# %%
tm.timeit(setup=setup,stmt=stmt2,number=1000)
# Out:
# 0.07590200001141056

# %%
tm.timeit(setup=setup,stmt=stmt3,number=1000)
# Out:
# 0.030768915952648968

# %%
# Time Methods with Date and Time

# %%
from datetime import datetime

# %%
myyear = 2023
mymonth = 5
myday = 24
myhour = 17
mymin = 30
mysec = 0

# %%
mydate = datetime(myyear,mymonth,myday,myhour,mymin,mysec)

# %%
mydate
# Out:
# datetime.datetime(2023, 5, 24, 17, 30)

# %%
mydate.day
# Out:
# 24

# %%
#datetime from series

# %%
dtseries = pd.Series(['May 24, 2023','04-29-1964','1969/11/09','6th Sept of 2001','01-08-1995'])

# %%
type(dtseries)
# Out:
# pandas.core.series.Series

# %%
dtseries
# Out:
# 0         May 24,2023
# 1          04-29-1964
# 2          1969/11/09
# 3    6th Sept of 2001
# 4          01-08-1995
# dtype: object

# %%
dtbdays = pd.to_datetime(dtseries,format='mixed')

# %%
dtbdays
# Out:
# 0   2023-05-24
# 1   1964-04-29
# 2   1969-11-09
# 3   2001-09-06
# 4   1995-01-08
# dtype: datetime64[ns]

# %%
dtbdays[0].year
# Out:
# 2023

# %%
dtbdays[0].month
# Out:
# 5

# %%
dtbdays[len(dtbdays)-1]
# Out:
# Timestamp('1995-01-08 00:00:00')

# %%
dtbdays[len(dtbdays)-1].month
# Out:
# 1

# %%
date_india = '08-01-1995'

# %%
pd.to_datetime(date_india)
# Out:
# Timestamp('1995-08-01 00:00:00')

# %%
pd.to_datetime(date_india).month
# Out:
# 8

# %%
pd.to_datetime(date_india,dayfirst=True)
# Out:
# Timestamp('1995-01-08 00:00:00')

# %%
pd.to_datetime(date_india,dayfirst=True).month
# Out:
# 1

# %%
pd.to_datetime('1995-01-08',dayfirst=True).month
#does not consider 08 as day
# Out:
# 8

# %%
pd.to_datetime('1995-01-08',yearfirst=True).month
# Out:
# 1

# %%
#custom format 
# https://docs.python.org/3/library/datetime.html#strftime-and-strptime-format-codes
pd.to_datetime('10--12--2000',format='%d--%m--%Y').month
# Out:
# 12

# %%
pd.to_datetime('10--12--2000',format='%m--%d--%Y').month
# Out:
# 10

# %%
pd.to_datetime('10--Sep--2000',format='%d--%b--%Y').month
# 'sept' is not recognized, only 'sep' or 'Sep' or 'SEP'
# Out:
# 9

# %%
pd.to_datetime('10th of September 2000').month
# Out:
# 9

# %%
# !ls '/Users/ada4sh/Documents/Study/Python/Python for ML and DScience/UNZIP_FOR_NOTEBOOKS_FINAL/03-Pandas'
# Out:
# 00-Series.ipynb
# 01-DataFrames.ipynb
# 02-Conditional-Filtering.ipynb
# 03-Useful-Methods.ipynb
# 04-Missing-Data.ipynb
# 05-Groupby-Operations-and-MultiIndex.ipynb
# 06-Combining-DataFrames.ipynb
# 07-Text-Methods.ipynb
# 08-Time-Methods.ipynb
# 09-Inputs-and-Outputs.ipynb
# 10-Pivot-Tables.ipynb
# 11-Pandas-Project-Exercise .ipynb
# 12-Pandas-Project-Exercise-Solution.ipynb
# RetailSales_BeerWineLiquor.csv
# Sales_Funnel_CRM.csv
# __pycache__
# example.csv
# example.xlsx
# hotel_booking_data.csv
# movie_scores.csv
# mpg.csv
# my_excel_file.xlsx
# new_file.csv
# new_workbook.xlsx
# newfile.csv
# reshaping_pivot.png
# sample_table.html
# simple.html
# tips.csv

# %%
dfdt = pd.read_csv('/Users/ada4sh/Documents/Study/Python/Python for ML and DScience/UNZIP_FOR_NOTEBOOKS_FINAL/03-Pandas/RetailSales_BeerWineLiquor.csv')

# %%
dfdt
# Out:
#            DATE  MRTSSM4453USN
# 0    1992-01-01           1509
# 1    1992-02-01           1541
# 2    1992-03-01           1597
# 3    1992-04-01           1675
# 4    1992-05-01           1822
# ..          ...            ...
# 335  2019-12-01           6630
# 336  2020-01-01           4388
# 337  2020-02-01           4533
# 338  2020-03-01           5562
# 339  2020-04-01           5207
#
# [340 rows x 2 columns]

# %%
dfdt['DATE']
# Out:
# 0      1992-01-01
# 1      1992-02-01
# 2      1992-03-01
# 3      1992-04-01
# 4      1992-05-01
#           ...
# 335    2019-12-01
# 336    2020-01-01
# 337    2020-02-01
# 338    2020-03-01
# 339    2020-04-01
# Name: DATE, Length: 340, dtype: object

# %%
dfdt['date_dt'] = pd.to_datetime(dfdt['DATE'])

# %%
dfdt
# Out:
#            DATE  MRTSSM4453USN    date_dt
# 0    1992-01-01           1509 1992-01-01
# 1    1992-02-01           1541 1992-02-01
# 2    1992-03-01           1597 1992-03-01
# 3    1992-04-01           1675 1992-04-01
# 4    1992-05-01           1822 1992-05-01
# ..          ...            ...        ...
# 335  2019-12-01           6630 2019-12-01
# 336  2020-01-01           4388 2020-01-01
# 337  2020-02-01           4533 2020-02-01
# 338  2020-03-01           5562 2020-03-01
# 339  2020-04-01           5207 2020-04-01
#
# [340 rows x 3 columns]

# %%
dfdt['date_dt']
# Out:
# 0     1992-01-01
# 1     1992-02-01
# 2     1992-03-01
# 3     1992-04-01
# 4     1992-05-01
#          ...
# 335   2019-12-01
# 336   2020-01-01
# 337   2020-02-01
# 338   2020-03-01
# 339   2020-04-01
# Name: date_dt, Length: 340, dtype: datetime64[ns]

# %%
dfdt['date_dt'].mean().year
# Out:
# 2006

# %%
# you can also mention while importing itself that a colimn should be considered as a datetime
dfdt = pd.read_csv('/Users/ada4sh/Documents/Study/Python/Python for ML and DScience/UNZIP_FOR_NOTEBOOKS_FINAL/03-Pandas/RetailSales_BeerWineLiquor.csv',parse_dates=[0])

# %%
dfdt['DATE']
# Out:
# 0     1992-01-01
# 1     1992-02-01
# 2     1992-03-01
# 3     1992-04-01
# 4     1992-05-01
#          ...
# 335   2019-12-01
# 336   2020-01-01
# 337   2020-02-01
# 338   2020-03-01
# 339   2020-04-01
# Name: DATE, Length: 340, dtype: datetime64[ns]

# %%
# you can perform some sampling operations on datetime columns 
dfdt = dfdt.set_index('DATE')

# %%
#Resample function has some aliases for 'rule' -- check below 
# https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#offset-aliases
# below rule=A means group by year, and then get mean per year 
dfdt.resample(rule='A').mean()
# Out:
#             MRTSSM4453USN
# DATE
# 1992-12-31    1807.250000
# 1993-12-31    1794.833333
# 1994-12-31    1841.750000
# 1995-12-31    1833.916667
# 1996-12-31    1929.750000
# 1997-12-31    2006.750000
# 1998-12-31    2115.166667
# 1999-12-31    2206.333333
# 2000-12-31    2375.583333
# 2001-12-31    2468.416667
# 2002-12-31    2491.166667
# 2003-12-31    2539.083333
# 2004-12-31    2682.416667
# 2005-12-31    2797.250000
# 2006-12-31    3001.333333
# 2007-12-31    3177.333333
# 2008-12-31    3292.000000
# 2009-12-31    3353.750000
# 2010-12-31    3450.083333
# 2011-12-31    3532.666667
# 2012-12-31    3697.083333
# 2013-12-31    3839.666667
# 2014-12-31    4023.833333
# 2015-12-31    4212.500000
# 2016-12-31    4434.416667
# 2017-12-31    4602.666667
# 2018-12-31    4830.666667
# 2019-12-31    4972.750000
# 2020-12-31    4922.500000

# %%
dfdt = pd.read_csv('/Users/ada4sh/Documents/Study/Python/Python for ML and DScience/UNZIP_FOR_NOTEBOOKS_FINAL/03-Pandas/RetailSales_BeerWineLiquor.csv',parse_dates=[0])

# %%
dfdt['DATE'].dt.month
# Out:
# 0       1
# 1       2
# 2       3
# 3       4
# 4       5
#        ..
# 335    12
# 336     1
# 337     2
# 338     3
# 339     4
# Name: DATE, Length: 340, dtype: int32

# %%
dfdt['DATE'].dt.year
# you can use dt.<whatyouwantfromdatetime> to fetch year, month, etc.
# Out:
# 0      1992
# 1      1992
# 2      1992
# 3      1992
# 4      1992
#        ...
# 335    2019
# 336    2020
# 337    2020
# 338    2020
# 339    2020
# Name: DATE, Length: 340, dtype: int32
